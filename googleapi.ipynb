# %%
import pandas as pd 
import requests
from config import API_KEY
import os

# %%
# Create a list of coordinates that separate Melbourne CBD into a 5x5 grid
NORTHEAST_LAT = -37.804372697115774
NORTHEAST_LNG = 144.9738931822595
SOUTHWEST_LAT = -37.82082971518847  
SOUTHWEST_LNG = 144.9551814533306  
-37.804372697115774, 144.9738931822595
DESIRED_GRID_LENGTH = 16  # start with 3 to get a 3x3 grid and so on...

grid_coordinates = []
epsilon = 1e-9  # because float comparisons can be imprecise
intermediate_grid_length = DESIRED_GRID_LENGTH - 1

lat_step_size = (NORTHEAST_LAT - SOUTHWEST_LAT) / intermediate_grid_length
lng_step_size = (NORTHEAST_LNG - SOUTHWEST_LNG) / intermediate_grid_length

lat = SOUTHWEST_LAT
while lat <= NORTHEAST_LAT + epsilon:
    lng = SOUTHWEST_LNG
    while lng <= NORTHEAST_LNG + epsilon:
        grid_coordinates.append((lat, lng))
        lng += lng_step_size
    lat += lat_step_size

print(grid_coordinates)
# Out:
# [(-37.82082971518847, 144.9551814533306), (-37.82082971518847, 144.95642890192585), (-37.82082971518847, 144.9576763505211), (-37.82082971518847, 144.95892379911635), (-37.82082971518847, 144.9601712477116), (-37.82082971518847, 144.96141869630685), (-37.82082971518847, 144.9626661449021), (-37.82082971518847, 144.96391359349735), (-37.82082971518847, 144.9651610420926), (-37.82082971518847, 144.96640849068785), (-37.82082971518847, 144.9676559392831), (-37.82082971518847, 144.96890338787836), (-37.82082971518847, 144.9701508364736), (-37.82082971518847, 144.97139828506886), (-37.82082971518847, 144.9726457336641), (-37.82082971518847, 144.97389318225936), (-37.81973258065029, 144.9551814533306), (-37.81973258065029, 144.95642890192585), (-37.81973258065029, 144.9576763505211), (-37.81973258065029, 144.95892379911635), (-37.81973258065029, 144.9601712477116), (-37.81973258065029, 144.96141869630685), (-37.81973258065029, 144.9626661449021), (-37.81973258065029, 144.96391359349735), (-37.81973258065029, 144.9651610420926), (-37.81973258065029, 144.96640849068785), (-37.81973258065029, 144.9676559392831), (-37.81973258065029, 144.96890338787836), (-37.81973258065029, 144.9701508364736), (-37.81973258065029, 144.97139828506886), (-37.81973258065029, 144.9726457336641), (-37.81973258065029, 144.97389318225936), (-37.81863544611211, 144.9551814533306), (-37.81863544611211, 144.95642890192585), (-37.81863544611211, 144.9576763505211), (-37.81863544611211, 144.95892379911635), (-37.81863544611211, 144.9601712477116), (-37.81863544611211, 144.96141869630685), (-37.81863544611211, 144.9626661449021), (-37.81863544611211, 144.96391359349735), (-37.81863544611211, 144.9651610420926), (-37.81863544611211, 144.96640849068785), (-37.81863544611211, 144.9676559392831), (-37.81863544611211, 144.96890338787836), (-37.81863544611211, 144.9701508364736), (-37.81863544611211, 144.97139828506886), (-37.81863544611211, 144.9726457336641), (-37.81863544611211, 144.97389318225936), (-37.817538311573934, 144.9551814533306), (-37.817538311573934, 144.95642890192585), (-37.817538311573934, 144.9576763505211), (-37.817538311573934, 144.95892379911635), (-37.817538311573934, 144.9601712477116), (-37.817538311573934, 144.96141869630685), (-37.817538311573934, 144.9626661449021), (-37.817538311573934, 144.96391359349735), (-37.817538311573934, 144.9651610420926), (-37.817538311573934, 144.96640849068785), (-37.817538311573934, 144.9676559392831), (-37.817538311573934, 144.96890338787836), (-37.817538311573934, 144.9701508364736), (-37.817538311573934, 144.97139828506886), (-37.817538311573934, 144.9726457336641), (-37.817538311573934, 144.97389318225936), (-37.816441177035756, 144.9551814533306), (-37.816441177035756, 144.95642890192585), (-37.816441177035756, 144.9576763505211), (-37.816441177035756, 144.95892379911635), (-37.816441177035756, 144.9601712477116), (-37.816441177035756, 144.96141869630685), (-37.816441177035756, 144.9626661449021), (-37.816441177035756, 144.96391359349735), (-37.816441177035756, 144.9651610420926), (-37.816441177035756, 144.96640849068785), (-37.816441177035756, 144.9676559392831), (-37.816441177035756, 144.96890338787836), (-37.816441177035756, 144.9701508364736), (-37.816441177035756, 144.97139828506886), (-37.816441177035756, 144.9726457336641), (-37.816441177035756, 144.97389318225936), (-37.81534404249758, 144.9551814533306), (-37.81534404249758, 144.95642890192585), (-37.81534404249758, 144.9576763505211), (-37.81534404249758, 144.95892379911635), (-37.81534404249758, 144.9601712477116), (-37.81534404249758, 144.96141869630685), (-37.81534404249758, 144.9626661449021), (-37.81534404249758, 144.96391359349735), (-37.81534404249758, 144.9651610420926), (-37.81534404249758, 144.96640849068785), (-37.81534404249758, 144.9676559392831), (-37.81534404249758, 144.96890338787836), (-37.81534404249758, 144.9701508364736), (-37.81534404249758, 144.97139828506886), (-37.81534404249758, 144.9726457336641), (-37.81534404249758, 144. ...

# %%
# Google Place API Function
def google_maps_restaurant(api_key, grid_coordinates, radius=175, max_iterations=3, min_ratings=35):
    url = 'https://maps.googleapis.com/maps/api/place/nearbysearch/json'
    restaurants = []

    for coord in grid_coordinates:  # At each grid coordinate, call google API 
        location = f"{coord[0]},{coord[1]}"
        npt = None
        iteration = 0

        while iteration < max_iterations:
            params = {
                'location': location,
                'radius': radius,
                'type': 'restaurant',
                'key': api_key,
            }
            if npt:  # Ensures first iteration does not error out (since npt = None first) + add page token to params for the next iteration
                params['pagetoken'] = npt

            response = requests.get(url, params=params).json()

            if 'results' in response:  # If restaurant found
                for item in response['results']:
                    user_ratings_total = item.get('user_ratings_total', 0)
                    
                    if user_ratings_total >= min_ratings:
                        try: 
                            restaurant_info = {
                                'name': item['name'],
                                'place_id': item['place_id'],
                                'price_level': item.get('price_level', None),
                                'lat': item['geometry']['location']['lat'],
                                'long': item['geometry']['location']['lng'],
                                'types': item['types'],
                                'address': item['vicinity']
                            }

                            restaurants.append(restaurant_info)
                        except KeyError as e:
                            print(f"Error occurred while processing item data: {e}")
                        
            if 'next_page_token' in response:
                npt = response['next_page_token']
                iteration += 1
            else:
                break

    return restaurants

# %%
# Calls API - CARE FOR API COSTS
restaurant_list = google_maps_restaurant(API_KEY, grid_coordinates)

# %%
restaurant_list
# Out:
# [{'name': 'Best Western Melbourne City Hotel',
#   'place_id': 'ChIJWXdjjVFd1moRh_LdkkyRy5s',
#   'price_level': None,
#   'lat': -37.8206276,
#   'long': 144.9551461,
#   'types': ['cafe',
#    'lodging',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   'address': '16 Spencer Street, Melbourne'},
#  {'name': 'Grand Hotel Melbourne',
#   'place_id': 'ChIJ3dmt61Fd1moRKaWbEW3hml4',
#   'price_level': None,
#   'lat': -37.8203025,
#   'long': 144.9543906,
#   'types': ['lodging',
#    'bar',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   'address': '33 Spencer Street, Docklands'},
#  {'name': "Domino's Pizza Flinders St",
#   'place_id': 'ChIJzUeRGVJd1moR8OAx5QG2svk',
#   'price_level': 1,
#   'lat': -37.8208688,
#   'long': 144.9563465,
#   'types': ['meal_delivery',
#    'meal_takeaway',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   'address': 'Tenancy 2C/555 Flinders Street, Melbourne'},
#  {'name': 'City Kebabs',
#   'place_id': 'ChIJJaylGVJd1moRjyu89QjaLrg',
#   'price_level': 1,
#   'lat': -37.8205272,
#   'long': 144.9561929,
#   'types': ['meal_takeaway',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   'address': '3/546 Flinders Street, Melbourne'},
#  {'name': 'Royale PizzaMelbourne',
#   'place_id': 'ChIJT5at6FFd1moRl7tSBihHz1I',
#   'price_level': None,
#   'lat': -37.8196912,
#   'long': 144.954892,
#   'types': ['meal_delivery',
#    'meal_takeaway',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   'address': '44/56 Spencer Street, Melbourne'},
#  {'name': 'Cherry and Twigs',
#   'place_id': 'ChIJJbxbHVJd1moRlmxHO37SS70',
#   'price_level': 2,
#   'lat': -37.8200371,
#   'long': 144.9557317,
#   'types': ['cafe',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   'address': 'Shop 1B/555 Flinders Lane, Melbourne'},
#  {'name': 'Restaurant 1903',
#   'place_id': 'ChIJlVbz5VFd1moRBbVdFgoTEVI',
#   'price_level': 1,
#   'lat': -37.8197325,
#   'long': 144.9547667,
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'address': '44 Spencer Street, Melbourne'},
#  {'name': 'Tokyo Maki - Melbourne',
#   'place_id': 'ChIJ0Ux_FlJd1moRZzHQVlx6dEs',
#   'price_level': 1,
#   'lat': -37.8207967,
#   'long': 144.956706,
#   'types': ['meal_delivery',
#    'meal_takeaway',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   'address': '547 Flinders Street, Melbourne'},
#  {'name': 'The Hardware Société',
#   'place_id': 'ChIJGTbCqEpd1moRvbLaxevnLtw',
#   'price_level': 2,
#   'lat': -37.8200386,
#   'long': 144.9566619,
#   'types': ['cafe',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   'address': '10 Katherine Place, Melbourne'},
#  {'name': 'Delhi Streets',
#   'place_id': 'ChIJW6n2CFJd1moRgzF7MAe-pSw',
#   'price_level': 1,
#   'lat': -37.81983400000001,
#   'long': 144.9564871,
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'address': '22 Katherine Place, Melbourne'},
#  {'name': 'Gaylord Indian Restaurant',
#   'place_id': 'ChIJ_XkoPMpC1moRe4ufdMTGZc0',
#   'price_level': 2,
#   'lat': -37.82063100000001,
#   'long': 144.9545136,
#   'types': ['meal_takeaway',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   'address': '33 Spencer Street, Docklands'},
#  {'name': "Nando's Northbank",
#   'place_id': 'ChIJSf9AFlJd1moRkvJT4i0d0UM',
#   'price_level': 2,
#   'lat': -37.820962,
#   'long': 144.9564753,
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'address': 'Central Tower, Northbank, 551 Flinders Street, Melbourne'},
#  {'name': 'Sirocco Restaurant & Bar',
#   'place_id': 'ChIJOV-E8VFd1moRYfNx1FsY7lk',
#   'price_level': 2,
#   'lat': -37.8201301,
#   'long': 144.9548865,
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'address': '575 Flinders Lane, Melbourne'},
#  {'name': 'CBD Kebabs',
#   'place_id': 'ChIJzd0I3U1d1moRa0JZOn5vwOo',
#   'price_level': 1,
#   'lat': -37.820521,
#   'long': 144.956143,
#   'types': ['meal_takeaway',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   'address': 'Meeting room/546 Flinders Street, Melbourne'},
#  {'name': "Olivier's Cafe",
#   'place_id': 'ChIJoe15klFd1moRRDR_qr-4chk',
#   'price_level': None,
#   'lat': -37.8204799,
#   'long': 144.9552898,
#   'types': ['restaurant',
#    'cafe',
#    'lodging',
#    'food',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   'address': '16 Spencer Street, Melbourne'},
#  {'name': 'Best Western Melbourne City Hotel',
#   'place_id': 'ChIJWXdjjVFd1moRh_LdkkyRy5s',
#   'price_level': None,
#   'lat': -37.8206276,
#   'long': 144.9551461,
#   'types': ['cafe',
#    'lodging',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   'address': '16 Spencer Street, Melbourne'},
#  {'name': 'Grain Store',
#   'place_id': 'ChIJEcl3801d1moRgOGlD-vbemk',
#   'price_level': 2,
#   'lat': -37.8197517,
#   'long': 144.956651,
#   'types': ['cafe',
#    'meal_delivery',
#    'meal_takeaway',
#    'restaurant',
#    'food',
#    'bar',
#    'point_of_interest',
#    'store',
#    'establishment'],
#   'address': '517 Flinders Lane, Melbourne'},
#  {'name': "Domino's Pizza Flinders St",
#   'place_id': 'ChIJzUeRGVJd1moR8OAx5QG2svk',
#   'price_level': 1,
#   'lat': -37.8208688,
#   'long': 144.9563465,
#   'types': ['meal_delivery',
#    'meal_takeaway',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   'address': 'Tenancy 2C/555 Flinders Street, Melbourne'},
#  {'name': 'The Hardware Société',
#   'place_id': 'ChIJGTbCqEpd1moRvbLaxevnLtw',
#   'price_level': 2,
#   'lat': -37.8200386,
#   'long': 144.9566619,
#   'types': ['cafe',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   'address': '10 Katherine Place, Melbourne'},
#  {'name': 'Tokyo Maki - Melbourne',
#   'place_id': 'ChIJ0Ux_FlJd1moRZzHQVlx6dEs',
#   'price_level': 1,
#   'lat': -37.8207967,
#   'long': 144.956706,
#   'types': ['meal_delivery',
#    'meal_takeaway',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   'address': '547 Flinders Street, Melbourne'},
#  {'name': 'City Kebabs',
#   'place_id': 'ChIJJaylGVJd1moRjyu89QjaLrg',
#   'price_level': 1,
#   'lat': -37.8205272,
#   'long': 144.9561929,
#   'types': ['meal_takeaway',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   'address': '3/546 Flinders Street, Melbourne'},
#  {'name': 'Cherry and Twigs',
#   'place_id': 'ChIJJbxbHVJd1moRlmxHO37SS70',
#   'price_level': 2,
#   'lat': -37.8200371,
#   'long': 144.9557317,
#   'types': ['cafe',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   'address': 'Shop 1B/555 Flinders Lane, Melbourne'},
#  {'name': 'Delhi Streets',
#   'place_id': 'ChIJW6n2CFJd1moRgzF7MAe-pSw',
#   'price_level': 1,
#   'lat': -37.81983400000001,
#   'long': 144.9564871,
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'address': '22 Katherine Place, Melbourne'},
#  {'name': 'State of Grace',
#   'place_id': 'ChIJmfW-qk1d1moRewnuCAqvfY4',
#   'price_level': 3,
#   'lat': -37.81975199999999,
#   'long': 144.956983,
#   'types': ['restaurant', 'food', 'bar', 'point_of_interest', 'establishment'],
#   'address': '27 King Street, Melbourne'},
#  {'name': "Nando's Northbank",
#   'place_id': 'ChIJSf9AFlJd1moRkvJT4i0d0UM',
#   'price_level': 2,
#   'lat': -37.820962,
#   'long': 144.9564753,
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'address': 'Central Tower, Northbank, 551 Flinders Street, Melbourne'},
#  {'name': 'Mr Huang Jin',
#   'place_id': 'ChIJFS1cvE1d1moRuewGEtWYJjk',
#   'price_level': 2,
#   'lat': -37.8197681,
#   'long': 144.9564472,
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'address': '24 Katherine Place, Melbourne'},
#  {'name': 'CBD Kebabs',
#   'place_id': 'ChIJzd0I3U1d1moRa0JZOn5vwOo',
#   'price_level': 1,
#   'lat': -37.820521,
#   'long': 144.956143,
#   'types': ['meal_takeaway',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   'address': 'Meeting room/546 Flinders Street, Melbourne'},
#  {'name': 'Mykonos',
#   'place_id': 'ChIJpzumX71d1moRO7IhZbPiFF8',
#   'price_level': None,
#   'lat': -37.8204905,
#   'long': 144.9564667,
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'address': '534-536 Flinders Street, Melbourne'},
#  {'name': 'Grain Store',
#   'place_id': 'ChIJEcl3801d1moRgOGlD-vbemk',
#   'price_level': 2,
#   'lat': -37.8197517,
#   'long': 144.956651,
#   'types': ['cafe',
#    'meal_delivery',
#    'meal_takeaway',
#    'bar',
#    'restaurant',
#    'food',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   'address': '517 Flinders Lane, Melbourne'},
#  {'name': "Domino's Pizza Flinders St",
#   'place_id': 'ChIJzUeRGVJd1moR8OAx5QG2svk',
#   'price_level': 1,
#   'lat': -37.8208688,
#   'long': 144.9563465,
#   'types': ['meal_delivery',
#    'meal_takeaway',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   'address': 'Tenancy 2C/555 Flinders Street, Melbourne'},
#  {'name': 'The Hardware Société',
#   'place_id': 'ChIJGTbCqEpd1moRvbLaxevnLtw',
#   'price_level': 2,
#   'lat': -37.8200386,
#   'long': 144.9566619,
#   'types': ['cafe',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   'address': '10 Katherine Place, Melbourne'},
#  {'name': 'Tokyo Maki - Melbourne',
#   'place_id': 'ChIJ0Ux_FlJd1moRZzHQVlx6dEs',
#   'price_level': 1,
#   'lat': -37.8207967,
#   'long': 144.956706,
#   'types': ['meal_delivery',
#    'meal_takeaway',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   'address': '547 Flinders Street, Melbourne'},
#  {'name': 'City Kebabs',
#   'place_id': 'ChIJJaylGVJd1moRjyu89QjaLrg',
#   'price_level': 1,
#   'lat': -37.8205272,
#   'long': 144.9561929,
#   'types': ['meal_takeaway',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   'address': '3/546 Flinders Street, Melbourne'},
#  {'name': 'State of Grace',
#   'place_id': 'ChIJmfW-qk1d1moRewnuCAqvfY4',
#   'price_level': 3,
#   'lat': -37.81975199999999,
#   'long': 144.956983,
#   'types': ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   'address': '27 King Street, Melbourne'},
#  {'name': 'Delhi Streets',
#   'place_id': 'ChIJW6n2CFJd1moRgzF7MAe-pSw',
#   'price_level': 1,
#   'lat': -37.81983400000001,
#   'long': 144.9564871,
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'address': '22 Katherine Place, Melbourne'},
#  {'name': "Nando's Northbank",
#   'place_id': 'ChIJSf9AFlJd1moRkvJT4i0d0UM',
#   'price_level': 2,
#   'lat': -37.820962,
#   'long': 144.9564753,
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'address': 'Central Tower, Northbank, 551 Flinders Street, Melbourne'},
#  {'name': 'Food Hall',
#   'place_id': 'ChIJ-SXuBfJd1moRVz1rR0kF2QQ',
#   'price_level': None,
#   'lat': -37.8209305,
#   'long': 144.9569342,
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'address': '11 Gem Place, Melbourne'},
#  {'name': 'K-Rib by Kass Kass',
#   'place_id': 'ChIJX8jmUTxd1moRhzMaI62bbDY',
#   'price_level': None,
#   'lat': -37.8200955,
#   'long': 144.9577489,
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'address': 'Shop1/500 Flinders Street, Melbourne'},
#  {'name': 'Viva Kebabs and grill',
#   'place_id': 'ChIJy8teB3Fd1moRrpWihwJD1ls',
#   'price_level': None,
#   'lat': -37.82029199999999,
#   'long': 144.9569223,
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'address': '520/522 Flinders Street, Melbourne'},
#  {'name': 'Mykonos',
#   'place_id': 'ChIJpzumX71d1moRO7IhZbPiFF8',
#   'price_level': None,
#   'lat': -37.8204905,
#   'long': 144.9564667,
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'address': '534-536 Flinders Street, Melbourne'},
#  {'name': 'Flinders kebab',
#   'place_id': 'ChIJ6WLi2n9D1moRoneWqHgHkuk',
#   'price_level': 1,
#   'lat': -37.8204247,
#   'long': 144.9564835,
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'address': '534 Flinders Street, Melbourne'},
#  {'name': 'Rockpool Bar & Grill',
#   'place_id': 'ChIJs-Q2IlNd1moRXYbJPnkbnjY',
#   'price_level': 4,
#   'lat': -37.8218482,
#   'long': 144.96027,
#   'types': ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   'address': 'Crown Casino, 8 Whiteman Street, Southbank'},
#  {'name': 'Nobu',
#   'place_id': 'ChIJs-Q2IlNd1moRSMORcPpPc54',
#   'price_level': 4,
#   'lat': -37.8220682,
#   'long': 144.959651,
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'address': 'Crown Riverwalk, Crown Melbourne, 8 Whiteman Street, Southbank'},
#  {'name': 'Bistro Guillaume',
#   'place_id': 'ChIJs-Q2IlNd1moRkCphqzaZs1Q',
#   'price_level': 3,
#   'lat': -37.8221868,
#   'long': 144.9594149,
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'address': '8, Riverside, Crown Melbourne, Whiteman Street, Southbank'},
#  {'name': 'Conservatory',
#   'place_id': 'ChIJs-Q2IlNd1moRGGzNOjgw9Hg',
#   'price_level': 3,
#   'lat': -37.82210269999999,
#   'long': 144.9598176,
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'address': '8, Level 1 Crown Towers, Whiteman Street, Southbank'},
#  {'name': 'Koko',
#   'place_id': 'ChIJs-Q2IlNd1moRcLgzy7bPCDQ',
#   'price_level': 3,
#   'lat': -37.8220786,
#   'long': 144.9598287,
#   'types': ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   'address': 'Level 3, Crown Towers, 8 Whiteman Street, Southbank'},
#  {'name': 'Spice Temple',
#   'place_id': 'ChIJwd0Cv1Jd1moRmT612H04gRc',
#   'price_level': 4,
#   'lat': -37.8219651,
#   'long': 144.9599672,
#   'types': ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   'address': '8 Whiteman Street, Southbank'},
#  {'name': 'Rosetta Ristorante',
#   'place_id': 'ChIJuf4fgVNd1moRCOxhBhnDtyM',
#   'price_level': 2,
#   'lat': -37.82158829999999,
#   'long': 144.9605757,
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'address': 'Crown Riverwalk, Crown Melbourne, 8 Whiteman Street, Southbank'},
#  {'name': 'Silks',
#   'place_id': 'ChIJs-Q2IlNd1moRoBwpphuZePA',
#   'price_level': 2,
#   'lat': -37.8218012,
#   'long': 144.9601499,
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'address': 'Level 1 Crown Towers, Crown Melbourne, 8 Whiteman St, Southbank'},
#  {'name': 'K-Rib by Kass Kass',
#   'place_id': 'ChIJX8jmUTxd1moRhzMaI62bbDY',
#   'price_level': None,
#   'lat': -37.8200955,
#   'long': 144.9577489,
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'address': 'Shop1/500 Flinders Street, Melbourne'},
#  {'name': 'Petanque Social',
#   'place_id': 'ChIJG_IY3rRd1moRf6JiNoE66_0',
#   'price_level': None,
#   'lat': -37.8221316,
#   'long': 144.959153,
#   'types': ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   'address': 'Crown Riverwalk, Crown Melbourne, 8 Whiteman Street, Southbank'},
#  {'name': 'Ging Thai',
#   'place_id': 'ChIJVVVVoVNd1moR6axK6ZfedDA',
#   'price_level': None,
#   'lat': -37.8223299,
#   'long': 144.9590778,
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'address': 'Crown Riverwalk, Crown Melbourne, 8 Whiteman Street, Southbank'},
#  {'name': 'Rockpool Bar & Grill',
#   'place_id': 'ChIJs-Q2IlNd1moRXYbJPnkbnjY',
#   'price_level': 4,
#   'lat': -37.8218482,
#   'long': 144.96027,
#   'types': ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   'address': 'Crown Casino, 8 Whiteman Street, Southbank'},
#  {'name': 'The Meat & Wine Co Southbank',
#   'place_id': 'ChIJjXmoUa1C1moRMhlWBIe9Jpg',
#   'price_level': 3,
#   'lat': -37.82154609999999,
#   'long': 144.961854,
#   'types': ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   'address': 'Freshwater Place, 3 Queens Bridge Street, Southbank'},
#  {'name': 'Nobu',
#   'place_id': 'ChIJs-Q2IlNd1moRSMORcPpPc54',
#   'price_level': 4,
#   'lat': -37.8220682,
#   'long': 144.959651,
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'address': 'Crown Riverwalk, Crown Melbourne, 8 Whiteman Street, Southbank'},
#  {'name': 'Conservatory',
#   'place_id': 'ChIJs-Q2IlNd1moRGGzNOjgw9Hg',
#   'price_level': 3,
#   'lat': -37.82210269999999,
#   'long': 144.9598176,
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'address': '8, Level 1 Crown Towers, Whiteman Street, Southbank'},
#  {'name': 'Bistro Guillaume',
#   'place_id': 'ChIJs-Q2IlNd1moRkCphqzaZs1Q',
#   'price_level': 3,
#   'lat': -37.8221868,
#   'long': 144.9594149,
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'address': '8, Riverside, Crown Melbourne, Whiteman Street, Southbank'},
#  {'name': 'Koko',
#   'place_id': 'ChIJs-Q2IlNd1moRcLgzy7bPCDQ',
#   'price_level': 3,
#   'lat': -37.8220786,
#   'long': 144.9598287,
#   'types': ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   'address': 'Level 3, Crown Towers, 8 Whiteman Street, Southbank'},
#  {'name': 'Rosetta Ristorante',
#   'place_id': 'ChIJuf4fgVNd1moRCOxhBhnDtyM',
#   'price_level': 2,
#   'lat': -37.82158829999999,
#   'long': 144.9605757,
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'address': 'Crown Riverwalk, Crown Melbourne, 8 Whiteman Street, Southbank'},
#  {'name': 'Spice Temple',
#   'place_id': 'ChIJwd0Cv1Jd1moRmT612H04gRc',
#   'price_level': 4,
#   'lat': -37.8219651,
#   'long': 144.9599672,
#   'types': ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   'address': '8 Whiteman Street, Southbank'},
#  {'name': 'The Waiting Room',
#   'place_id': 'ChIJs-Q2IlNd1moRWbKiXqiW7L8',
#   'price_level': 2,
#   'lat': -37.82205,
#   'long': 144.9602679,
#   'types': ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   'address': 'Crown Towers, Crown Melbourne, 8 Whiteman Street, Southbank'},
#  {'name': 'Silks',
#   'place_id': 'ChIJs-Q2IlNd1moRoBwpphuZePA',
#   'price_level': 2,
#   'lat': -37.8218012,
#   'long': 144.9601499,
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'address': 'Level 1 Crown Towers, Crown Melbourne, 8 Whiteman St, Southbank'},
#  {'name': 'Petanque Social',
#   'place_id': 'ChIJG_IY3rRd1moRf6JiNoE66_0',
#   'price_level': None,
#   'lat': -37.8221316,
#   'long': 144.959153,
#   'types': ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   'address': 'Crown Riverwalk, Crown Melbourne, 8 Whiteman Street, Southbank'},
#  {'name': 'Left Bank Melbourne Restaurant & Cocktail Bar',
#   'place_id': 'ChIJFwC1lrJC1moRjtLuCpWlcF0',
#   'price_level': 2,
#   'lat': -37.8210084,
#   'long': 144.9628614,
#   'types': ['restaurant', 'bar', 'food', 'point_of_interest', 'establishment'],
#   'address': '1 Southbank Boulevard, Southbank'},
#  {'name': 'The Meat & Wine Co Southbank',
#   'place_id': 'ChIJjXmoUa1C1moRMhlWBIe9Jpg',
#   'price_level': 3,
#   'lat': -37.82154609999999,
#   'long': 144.961854,
#   'types': ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   'address': 'Freshwater Place, 3 Queens Bridge Street, Southbank'},
#  {'name': 'Rockpool Bar & Grill',
#   'place_id': 'ChIJs-Q2IlNd1moRXYbJPnkbnjY',
#   'price_level': 4,
#   'lat': -37.8218482,
#   'long': 144.96027,
#   'types': ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   'address': 'Crown Casino, 8 Whiteman Street, Southbank'},
#  {'name': 'Subway',
#   'place_id': 'ChIJA_x5Xq1C1moRx4hHk3neWoE',
#   'price_level': 1,
#   'lat': -37.8214708,
#   'long': 144.9621092,
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'address': 'Tenancy 6R/3 Freshwater Place, Southbank'},
#  {'name': "Criniti's Southbank",
#   'place_id': 'ChIJ0w7Po7JC1moRkfnUvgHePjQ',
#   'price_level': 3,
#   'lat': -37.8214199,
#   'long': 144.9622424,
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'address': '645 Freshwater Place, Southbank'},
#  {'name': 'Rosetta Ristorante',
#   'place_id': 'ChIJuf4fgVNd1moRCOxhBhnDtyM',
#   'price_level': 2,
#   'lat': -37.82158829999999,
#   'long': 144.9605757,
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'address': 'Crown Riverwalk, Crown Melbourne, 8 Whiteman Street, Southbank'},
#  {'name': 'The Breslin Bar & Grill',
#   'place_id': 'ChIJ6eEhZa1C1moR4Ls34LGLXvE',
#   'price_level': 2,
#   'lat': -37.82084990000001,
#   'long': 144.9629618,
#   'types': ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   'address': '1 Southbank Boulevard, Southbank'},
#  {'name': 'Soho Restaurant and Bar',
#   'place_id': 'ChIJ2d9nj7JC1moRvdqDm0DSNCQ',
#   'price_level': 2,
#   'lat': -37.8207812,
#   'long': 144.9632448,
#   'types': ['restaurant', 'bar', 'food', 'point_of_interest', 'establishment'],
#   'address': '2/4 Riverside Quay, Southbank'},
#  {'name': "McDonald's",
#   'place_id': 'ChIJ28UvnrJC1moRGJpeYP_5wSA',
#   'price_level': 1,
#   'lat': -37.8214104,
#   'long': 144.9621472,
#   'types': ['meal_takeaway',
#    'cafe',
#    'store',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   'address': 'Queens Bridge Street, Southbank'},
#  {'name': 'Silks',
#   'place_id': 'ChIJs-Q2IlNd1moRoBwpphuZePA',
#   'price_level': 2,
#   'lat': -37.8218012,
#   'long': 144.9601499,
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'address': 'Level 1 Crown Towers, Crown Melbourne, 8 Whiteman St, Southbank'},
#  {'name': 'The Waiting Room',
#   'place_id': 'ChIJs-Q2IlNd1moRWbKiXqiW7L8',
#   'price_level': 2,
#   'lat': -37.82205,
#   'long': 144.9602679,
#   'types': ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   'address': 'Crown Towers, Crown Melbourne, 8 Whiteman Street, Southbank'},
#  {'name': 'Sushi n Poke',
#   'place_id': 'ChIJv_KyHH1D1moRTnwAqy1g2oU',
#   'price_level': None,
#   'lat': -37.8214493,
#   'long': 144.9621923,
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'address': '8r/3 Freshwater Place, Southbank'},
#  {'name': 'VPR Asian Street Food',
#   'place_id': 'ChIJMx7VXq1C1moRlJvqmU1I9BU',
#   'price_level': None,
#   'lat': -37.8218125,
#   'long': 144.9621568,
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'address': '19r/3 Freshwater Place, Southbank'},
#  {'name': 'Five Guys',
#   'place_id': 'ChIJTcSq4QpD1moRmWg3RTSBMtU',
#   'price_level': None,
#   'lat': -37.8216754,
#   'long': 144.9624032,
#   'types': ['meal_takeaway',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   'address': '3 Freshwater Place, Southbank'},
#  {'name': 'Left Bank Melbourne Restaurant & Cocktail Bar',
#   'place_id': 'ChIJFwC1lrJC1moRjtLuCpWlcF0',
#   'price_level': 2,
#   'lat': -37.8210084,
#   'long': 144.9628614,
#   'types': ['restaurant', 'bar', 'food', 'point_of_interest', 'establishment'],
#   'address': '1 Southbank Boulevard, Southbank'},
#  {'name': 'Hopscotch Melbourne',
#   'place_id': 'ChIJA8Rg8bJC1moRmF1fVyw4iqg',
#   'price_level': 2,
#   'lat': -37.820722,
#   'long': 144.963457,
#   'types': ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   'address': 'Ground Floor, 4 Riverside Quay, Southbank'},
#  {'name': 'The Meat & Wine Co Southbank',
#   'place_id': 'ChIJjXmoUa1C1moRMhlWBIe9Jpg',
#   'price_level': 3,
#   'lat': -37.82154609999999,
#   'long': 144.961854,
#   'types': ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   'address': 'Freshwater Place, 3 Queens Bridge Street, Southbank'},
#  {'name': 'Ludlow Bar & Dining Room',
#   'place_id': 'ChIJZXSj9bJC1moRD5mvuOcEUPI',
#   'price_level': 2,
#   'lat': -37.820667,
#   'long': 144.963784,
#   'types': ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   'address': '6 Riverside Quay, Southbank'},
#  {'name': 'Subway',
#   'place_id': 'ChIJA_x5Xq1C1moRx4hHk3neWoE',
#   'price_level': 1,
#   'lat': -37.8214708,
#   'long': 144.9621092,
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'address': 'Tenancy 6R/3 Freshwater Place, Southbank'},
#  {'name': 'The Breslin Bar & Grill',
#   'place_id': 'ChIJ6eEhZa1C1moR4Ls34LGLXvE',
#   'price_level': 2,
#   'lat': -37.82084990000001,
#   'long': 144.9629618,
#   'types': ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   'address': '1 Southbank Boulevard, Southbank'},
#  {'name': 'Soho Restaurant and Bar',
#   'place_id': 'ChIJ2d9nj7JC1moRvdqDm0DSNCQ',
#   'price_level': 2,
#   'lat': -37.8207812,
#   'long': 144.9632448,
#   'types': ['restaurant', 'bar', 'food', 'point_of_interest', 'establishment'],
#   'address': '2/4 Riverside Quay, Southbank'},
#  {'name': "Criniti's Southbank",
#   'place_id': 'ChIJ0w7Po7JC1moRkfnUvgHePjQ',
#   'price_level': 3,
#   'lat': -37.8214199,
#   'long': 144.9622424,
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'address': '645 Freshwater Place, Southbank'},
#  {'name': 'Belgian Beer Cafe',
#   'place_id': 'ChIJpzMMZ7JC1moRw81gAuNuexI',
#   'price_level': 2,
#   'lat': -37.8214975,
#   'long': 144.9643633,
#   'types': ['cafe',
#    'bar',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   'address': '5 Riverside Quay, Southbank'},
#  {'name': "McDonald's",
#   'place_id': 'ChIJ28UvnrJC1moRGJpeYP_5wSA',
#   'price_level': 1,
#   'lat': -37.8214104,
#   'long': 144.9621472,
#   'types': ['meal_takeaway',
#    'cafe',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'store',
#    'establishment'],
#   'address': 'Queens Bridge Street, Southbank'},
#  {'name': 'Old Man Pho Southbank - Vietnamese Restaurant',
#   'place_id': 'ChIJfS2hGdpD1moR6PmNDzQdW4M',
#   'price_level': None,
#   'lat': -37.8210966,
#   'long': 144.9630499,
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'address': 'T2/1 Southbank Boulevard, Southbank'},
#  {'name': 'Infinite Wasabi',
#   'place_id': 'ChIJQX_3jbJC1moRwI-QdZK3f3g',
#   'price_level': None,
#   'lat': -37.8210698,
#   'long': 144.9632597,
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'address': '3/4 Riverside Quay, Southbank'},
#  {'name': 'Thailander Riverside Quay',
#   'place_id': 'ChIJdQILjrJC1moRkAesYODW0jk',
#   'price_level': None,
#   'lat': -37.8211391,
#   'long': 144.9633121,
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'address': '4/4 Riverside Quay, Southbank'},
#  {'name': 'Sushi n Poke',
#   'place_id': 'ChIJv_KyHH1D1moRTnwAqy1g2oU',
#   'price_level': None,
#   'lat': -37.8214493,
#   'long': 144.9621923,
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'address': '8r/3 Freshwater Place, Southbank'},
#  {'name': 'Yarra Botanica',
#   'place_id': 'ChIJ36msuKFD1moRRp5EwQvZODQ',
#   'price_level': 2,
#   'lat': -37.82030479999999,
#   'long': 144.9635772,
#   'types': ['restaurant', 'bar', 'food', 'point_of_interest', 'establishment'],
#   'address': 'Southbank Promenade, Southbank'},
#  {'name': 'Five Guys',
#   'place_id': 'ChIJTcSq4QpD1moRmWg3RTSBMtU',
#   'price_level': None,
#   'lat': -37.8216754,
#   'long': 144.9624032,
#   'types': ['meal_takeaway',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   'address': '3 Freshwater Place, Southbank'},
#  {'name': 'Left Bank Melbourne Restaurant & Cocktail Bar',
#   'place_id': 'ChIJFwC1lrJC1moRjtLuCpWlcF0',
#   'price_level': 2,
#   'lat': -37.8210084,
#   'long': 144.9628614,
#   'types': ['restaurant', 'bar', 'food', 'point_of_interest', 'establishment'],
#   'address': '1 Southbank Boulevard, Southbank'},
#  {'name': 'Hopscotch Melbourne',
#   'place_id': 'ChIJA8Rg8bJC1moRmF1fVyw4iqg',
#   'price_level': 2,
#   'lat': -37.820722,
#   'long': 144.963457,
#   'types': ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   'address': 'Ground Floor, 4 Riverside Quay, Southbank'},
#  {'name': 'Melba Restaurant',
#   'place_id': 'ChIJreaFNbJC1moRqxx1nrTb6jc',
#   'price_level': 3,
#   'lat': -37.8206644,
#   'long': 144.965638,
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'address': '1 Southgate Avenue, Southbank'},
#  {'name': 'Ludlow Bar & Dining Room',
#   'place_id': 'ChIJZXSj9bJC1moRD5mvuOcEUPI',
#   'price_level': 2,
#   'lat': -37.820667,
#   'long': 144.963784,
#   'types': ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   'address': '6 Riverside Quay, Southbank'},
#  {'name': 'Ponyfish Island',
#   'place_id': 'ChIJY4qztrNC1moR2ltTyJU3oe0',
#   'price_level': 2,
#   'lat': -37.81988339999999,
#   'long': 144.9650018,
#   'types': ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   'address': 'Evan Walker Bridge, Southbank'},
#  {'name': 'Belgian Beer Cafe',
#   'place_id': 'ChIJpzMMZ7JC1moRw81gAuNuexI',
#   'price_level': 2,
#   'lat': -37.8214975,
#   'long': 144.9643633,
#   'types': ['cafe',
#    'bar',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   'address': '5 Riverside Quay, Southbank'},
#  {'name': 'Soho Restaurant and Bar',
#   'place_id': 'ChIJ2d9nj7JC1moRvdqDm0DSNCQ',
#   'price_level': 2,
#   'lat': -37.8207812,
#   'long': 144.9632448,
#   'types': ['restaurant', 'bar', 'food', 'point_of_interest', 'establishment'],
#   'address': '2/4 Riverside Quay, Southbank'},
#  {'name': 'The Breslin Bar & Grill',
#   'place_id': 'ChIJ6eEhZa1C1moR4Ls34LGLXvE',
#   'price_level': 2,
#   'lat': -37.82084990000001,
#   'long': 144.9629618,
#   'types': ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   'address': '1 Southbank Boulevard, Southbank'},
#  {'name': 'Eureka 89 Dining & Events - Fine Dining Restaurant Melbourne',
#   'place_id': 'ChIJZ-xZZrJC1moRuDmVvlWC5fM',
#   'price_level': 3,
#   'lat': -37.8213341,
#   'long': 144.9646982,
#   'types': ['restaurant', 'bar', 'food', 'point_of_interest', 'establishment'],
#   'address': 'Eureka Tower, Level 89/7 Riverside Quay, Southbank'},
#  {'name': 'Subway',
#   'place_id': 'ChIJA_x5Xq1C1moRx4hHk3neWoE',
#   'price_level': 1,
#   'lat': -37.8214708,
#   'long': 144.9621092,
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'address': 'Tenancy 6R/3 Freshwater Place, Southbank'},
#  {'name': "Criniti's Southbank",
#   'place_id': 'ChIJ0w7Po7JC1moRkfnUvgHePjQ',
#   'price_level': 3,
#   'lat': -37.8214199,
#   'long': 144.9622424,
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'address': '645 Freshwater Place, Southbank'},
#  {'name': 'Aria Bar & Lounge',
#   'place_id': 'ChIJreaFNbJC1moRA46INPc9E4I',
#   'price_level': None,
#   'lat': -37.820681,
#   'long': 144.9656782,
#   'types': ['restaurant', 'bar', 'food', 'point_of_interest', 'establishment'],
#   'address': '1 Southgate Avenue, Southbank'},
#  {'name': 'Spirit Of Melbourne Cruising Restaurant',
#   'place_id': 'ChIJDVZTyLNC1moRm8_kwadoR6I',
#   'price_level': None,
#   'lat': -37.81994959999999,
#   'long': 144.9655336,
#   'types': ['restaurant',
#    'tourist_attraction',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   'address': 'Southbank Promenade, Southbank Berth 1, Melbourne'},
#  {'name': 'DOC Pizza & Mozzarella Bar - Southbank',
#   'place_id': 'ChIJ_f-j-UtD1moRr7bRglyyLaM',
#   'price_level': None,
#   'lat': -37.8208482,
#   'long': 144.963894,
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'address': '6 Riverside Quay, Southbank'},
#  {'name': 'Dagwood Deli',
#   'place_id': 'ChIJjbLvylhD1moRRvSVFGzPedg',
#   'price_level': None,
#   'lat': -37.8208482,
#   'long': 144.963894,
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'address': 'tenancy 6/6 Riverside Quay, Southbank'},
#  {'name': 'Asado',
#   'place_id': 'ChIJ4xaW-AJD1moR-4fAxvspuR0',
#   'price_level': 3,
#   'lat': -37.8208984,
#   'long': 144.9640633,
#   'types': ['restaurant', 'bar', 'food', 'point_of_interest', 'establishment'],
#   'address': '6 Riverside Quay, Southbank'},
#  {'name': 'Thailander Riverside Quay',
#   'place_id': 'ChIJdQILjrJC1moRkAesYODW0jk',
#   'price_level': None,
#   'lat': -37.8211391,
#   'long': 144.9633121,
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'address': '4/4 Riverside Quay, Southbank'},
#  {'name': 'Infinite Wasabi',
#   'place_id': 'ChIJQX_3jbJC1moRwI-QdZK3f3g',
#   'price_level': None,
#   'lat': -37.8210698,
#   'long': 144.9632597,
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'address': '3/4 Riverside Quay, Southbank'},
#  {'name': 'La Camera Southgate',
#   'place_id': 'ChIJ9f7HQrJC1moRwo_U9X7VL-E',
#   'price_level': 2,
#   'lat': -37.8200963,
#   'long': 144.966676,
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'address': '3 Southgate Avenue, Southbank'},
#  {'name': 'Melba Restaurant',
#   'place_id': 'ChIJreaFNbJC1moRqxx1nrTb6jc',
#   'price_level': 3,
#   'lat': -37.8206644,
#   'long': 144.965638,
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'address': '1 Southgate Avenue, Southbank'},
#  {'name': 'Hopscotch Melbourne',
#   'place_id': 'ChIJA8Rg8bJC1moRmF1fVyw4iqg',
#   'price_level': 2,
#   'lat': -37.820722,
#   'long': 144.963457,
#   'types': ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   'address': 'Ground Floor, 4 Riverside Quay, Southbank'},
#  {'name': 'BearBrass',
#   'place_id': 'ChIJgZOibbFC1moRMjs9MlqIuIc',
#   'price_level': 2,
#   'lat': -37.8201819,
#   'long': 144.9658567,
#   'types': ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   'address': 'GR3A/3 Southgate Avenue, Southbank'},
#  {'name': "PJ O'Brien's Irish Pub",
#   'place_id': 'ChIJgZOibbFC1moRjJ5c8xm1eWE',
#   'price_level': 2,
#   'lat': -37.8203722,
#   'long': 144.9659504,
#   'types': ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   'address': 'G14 / 15, 16/3 Southgate Avenue, Southbank'},
#  {'name': 'Red Emperor (Southgate) Chinese Restaurant',
#   'place_id': 'ChIJgZOibbFC1moREGFW5OuNjPk',
#   'price_level': 2,
#   'lat': -37.82008139999999,
#   'long': 144.9664159,
#   'types': ['meal_delivery',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   'address': 'M10/3 Southgate Avenue, Southbank'},
#  {'name': 'Tutto Bene',
#   'place_id': 'ChIJreaFNbJC1moRpXUSN5IQbmk',
#   'price_level': 2,
#   'lat': -37.8202591,
#   'long': 144.9659072,
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'address': 'M28/3 Southgate Avenue, Southbank'},
#  {'name': 'Ludlow Bar & Dining Room',
#   'place_id': 'ChIJZXSj9bJC1moRD5mvuOcEUPI',
#   'price_level': 2,
#   'lat': -37.820667,
#   'long': 144.963784,
#   'types': ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   'address': '6 Riverside Quay, Southbank'},
#  {'name': 'Miyako Japanese Cuisine & Teppanyaki',
#   'place_id': 'ChIJ4QDlhK1C1moRHe7gAH08xSo',
#   'price_level': 2,
#   'lat': -37.82013779999999,
#   'long': 144.9665086,
#   'types': ['restaurant',
#    'meal_takeaway',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   'address': 'Southgate Arts & Leisure Precinct, Shop, UR2/3 Southgate Avenue, Southbank'},
#  {'name': 'Ponyfish Island',
#   'place_id': 'ChIJY4qztrNC1moR2ltTyJU3oe0',
#   'price_level': 2,
#   'lat': -37.81988339999999,
#   'long': 144.9650018,
#   'types': ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   'address': 'Evan Walker Bridge, Southbank'},
#  {'name': 'The Deck Southbank',
#   'place_id': 'ChIJgZOibbFC1moRsAR-TgIQ340',
#   'price_level': 3,
#   'lat': -37.8201534,
#   'long': 144.9668346,
#   'types': ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   'address': 'UPPER, LEVEL U1/2 Southgate Avenue, Southbank'},
#  {'name': 'Belgian Beer Cafe',
#   'place_id': 'ChIJpzMMZ7JC1moRw81gAuNuexI',
#   'price_level': 2,
#   'lat': -37.8214975,
#   'long': 144.9643633,
#   'types': ['bar',
#    'cafe',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   'address': '5 Riverside Quay, Southbank'},
#  {'name': 'Eureka 89 Dining & Events - Fine Dining Restaurant Melbourne',
#   'place_id': 'ChIJZ-xZZrJC1moRuDmVvlWC5fM',
#   'price_level': 3,
#   'lat': -37.8213341,
#   'long': 144.9646982,
#   'types': ['restaurant', 'bar', 'food', 'point_of_interest', 'establishment'],
#   'address': 'Eureka Tower, Level 89/7 Riverside Quay, Southbank'},
#  {'name': 'Southgate',
#   'place_id': 'ChIJreaFNbJC1moRsVLa8Nh49SQ',
#   'price_level': None,
#   'lat': -37.8203389,
#   'long': 144.9660726,
#   'types': ['restaurant',
#    'art_gallery',
#    'bar',
#    'cafe',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   'address': '3 Southgate Avenue, Southbank'},
#  {'name': 'Spirit Of Melbourne Cruising Restaurant',
#   'place_id': 'ChIJDVZTyLNC1moRm8_kwadoR6I',
#   'price_level': None,
#   'lat': -37.81994959999999,
#   'long': 144.9655336,
#   'types': ['restaurant',
#    'tourist_attraction',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   'address': 'Southbank Promenade, Southbank Berth 1, Melbourne'},
#  {'name': "Roll'd Southgate",
#   'place_id': 'ChIJffIV0rNC1moRSEgzuMU4gq8',
#   'price_level': None,
#   'lat': -37.82023239999999,
#   'long': 144.9662985,
#   'types': ['meal_takeaway',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   'address': 'Southgate Melbourne, Tenancy G2/3 Southgate Avenue, Southbank'},
#  {'name': 'Bluetrain',
#   'place_id': 'ChIJiVdW17NC1moR-szxoi5qpgo',
#   'price_level': 2,
#   'lat': -37.8201184,
#   'long': 144.9662684,
#   'types': ['restaurant',
#    'cafe',
#    'store',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   'address': '3 Southgate Avenue, Southbank'},
#  {'name': 'Aria Bar & Lounge',
#   'place_id': 'ChIJreaFNbJC1moRA46INPc9E4I',
#   'price_level': None,
#   'lat': -37.820681,
#   'long': 144.9656782,
#   'types': ['restaurant', 'bar', 'food', 'point_of_interest', 'establishment'],
#   'address': '1 Southgate Avenue, Southbank'},
#  {'name': 'Waterfront Southgate',
#   'place_id': 'ChIJs-Q2IlNd1moRupUM9Le77E4',
#   'price_level': 3,
#   'lat': -37.8202217,
#   'long': 144.9656542,
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'address': 'Southgate Precinct, 20/3 Southgate Avenue, Southbank'},
#  {'name': 'La Camera Southgate',
#   'place_id': 'ChIJ9f7HQrJC1moRwo_U9X7VL-E',
#   'price_level': 2,
#   'lat': -37.8200963,
#   'long': 144.966676,
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'address': '3 Southgate Avenue, Southbank'},
#  {'name': 'Melba Restaurant',
#   'place_id': 'ChIJreaFNbJC1moRqxx1nrTb6jc',
#   'price_level': 3,
#   'lat': -37.8206644,
#   'long': 144.965638,
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'address': '1 Southgate Avenue, Southbank'},
#  {'name': 'BearBrass',
#   'place_id': 'ChIJgZOibbFC1moRMjs9MlqIuIc',
#   'price_level': 2,
#   'lat': -37.8201819,
#   'long': 144.9658567,
#   'types': ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   'address': 'GR3A/3 Southgate Avenue, Southbank'},
#  {'name': 'Red Emperor (Southgate) Chinese Restaurant',
#   'place_id': 'ChIJgZOibbFC1moREGFW5OuNjPk',
#   'price_level': 2,
#   'lat': -37.82008139999999,
#   'long': 144.9664159,
#   'types': ['meal_delivery',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   'address': 'M10/3 Southgate Avenue, Southbank'},
#  {'name': 'Miyako Japanese Cuisine & Teppanyaki',
#   'place_id': 'ChIJ4QDlhK1C1moRHe7gAH08xSo',
#   'price_level': 2,
#   'lat': -37.82013779999999,
#   'long': 144.9665086,
#   'types': ['restaurant',
#    'meal_takeaway',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   'address': 'Southgate Arts & Leisure Precinct, Shop, UR2/3 Southgate Avenue, Southbank'},
#  {'name': "PJ O'Brien's Irish Pub",
#   'place_id': 'ChIJgZOibbFC1moRjJ5c8xm1eWE',
#   'price_level': 2,
#   'lat': -37.8203722,
#   'long': 144.9659504,
#   'types': ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   'address': 'G14 / 15, 16/3 Southgate Avenue, Southbank'},
#  {'name': 'Tutto Bene',
#   'place_id': 'ChIJreaFNbJC1moRpXUSN5IQbmk',
#   'price_level': 2,
#   'lat': -37.8202591,
#   'long': 144.9659072,
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'address': 'M28/3 Southgate Avenue, Southbank'},
#  {'name': 'The Deck Southbank',
#   'place_id': 'ChIJgZOibbFC1moRsAR-TgIQ340',
#   'price_level': 3,
#   'lat': -37.8201534,
#   'long': 144.9668346,
#   'types': ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   'address': 'UPPER, LEVEL U1/2 Southgate Avenue, Southbank'},
#  {'name': 'Saké Restaurant & Bar',
#   'place_id': 'ChIJNU4yR7FC1moRjYwkSIJQblo',
#   'price_level': 3,
#   'lat': -37.8199177,
#   'long': 144.9677708,
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'address': '100 Saint Kilda Road, Southbank'},
#  {'name': 'Ponyfish Island',
#   'place_id': 'ChIJY4qztrNC1moR2ltTyJU3oe0',
#   'price_level': 2,
#   'lat': -37.81988339999999,
#   'long': 144.9650018,
#   'types': ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   'address': 'Evan Walker Bridge, Southbank'},
#  {'name': "Roll'd Southgate",
#   'place_id': 'ChIJffIV0rNC1moRSEgzuMU4gq8',
#   'price_level': None,
#   'lat': -37.82023239999999,
#   'long': 144.9662985,
#   'types': ['meal_takeaway',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   'address': 'Southgate Melbourne, Tenancy G2/3 Southgate Avenue, Southbank'},
#  {'name': 'Bluetrain',
#   'place_id': 'ChIJiVdW17NC1moR-szxoi5qpgo',
#   'price_level': 2,
#   'lat': -37.8201184,
#   'long': 144.9662684,
#   'types': ['restaurant',
#    'cafe',
#    'food',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   'address': '3 Southgate Avenue, Southbank'},
#  {'name': 'Southgate',
#   'place_id': 'ChIJreaFNbJC1moRsVLa8Nh49SQ',
#   'price_level': None,
#   'lat': -37.8203389,
#   'long': 144.9660726,
#   'types': ['restaurant',
#    'art_gallery',
#    'cafe',
#    'bar',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   'address': '3 Southgate Avenue, Southbank'},
#  {'name': "Grill'd Southgate",
#   'place_id': 'ChIJwyFHM7JC1moR082aaKSzBEc',
#   'price_level': 2,
#   'lat': -37.819991,
#   'long': 144.9668681,
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'address': 'Shop G32 Southgate Restaurant Precinct, Southgate Avenue'},
#  {'name': 'Spirit Of Melbourne Cruising Restaurant',
#   'place_id': 'ChIJDVZTyLNC1moRm8_kwadoR6I',
#   'price_level': None,
#   'lat': -37.81994959999999,
#   'long': 144.9655336,
#   'types': ['restaurant',
#    'tourist_attraction',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   'address': 'Southbank Promenade, Southbank Berth 1, Melbourne'},
#  {'name': 'Aria Bar & Lounge',
#   'place_id': 'ChIJreaFNbJC1moRA46INPc9E4I',
#   'price_level': None,
#   'lat': -37.820681,
#   'long': 144.9656782,
#   'types': ['restaurant', 'bar', 'food', 'point_of_interest', 'establishment'],
#   'address': '1 Southgate Avenue, Southbank'},
#  {'name': 'Eureka 89 Dining & Events - Fine Dining Restaurant Melbourne',
#   'place_id': 'ChIJZ-xZZrJC1moRuDmVvlWC5fM',
#   'price_level': 3,
#   'lat': -37.8213341,
#   'long': 144.9646982,
#   'types': ['restaurant', 'bar', 'food', 'point_of_interest', 'establishment'],
#   'address': 'Eureka Tower, Level 89/7 Riverside Quay, Southbank'},
#  {'name': 'Waterfront Southgate',
#   'place_id': 'ChIJs-Q2IlNd1moRupUM9Le77E4',
#   'price_level': 3,
#   'lat': -37.8202217,
#   'long': 144.9656542,
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'address': 'Southgate Precinct, 20/3 Southgate Avenue, Southbank'},
#  {'name': 'La Camera Southgate',
#   'place_id': 'ChIJ9f7HQrJC1moRwo_U9X7VL-E',
#   'price_level': 2,
#   'lat': -37.8200963,
#   'long': 144.966676,
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'address': '3 Southgate Avenue, Southbank'},
#  {'name': 'Red Emperor (Southgate) Chinese Restaurant',
#   'place_id': 'ChIJgZOibbFC1moREGFW5OuNjPk',
#   'price_level': 2,
#   'lat': -37.82008139999999,
#   'long': 144.9664159,
#   'types': ['meal_delivery',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   'address': 'M10/3 Southgate Avenue, Southbank'},
#  {'name': 'Miyako Japanese Cuisine & Teppanyaki',
#   'place_id': 'ChIJ4QDlhK1C1moRHe7gAH08xSo',
#   'price_level': 2,
#   'lat': -37.82013779999999,
#   'long': 144.9665086,
#   'types': ['restaurant',
#    'meal_takeaway',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   'address': 'Southgate Arts & Leisure Precinct, Shop, UR2/3 Southgate Avenue, Southbank'},
#  {'name': 'Saké Restaurant & Bar',
#   'place_id': 'ChIJNU4yR7FC1moRjYwkSIJQblo',
#   'price_level': 3,
#   'lat': -37.8199177,
#   'long': 144.9677708,
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'address': '100 Saint Kilda Road, Southbank'},
#  {'name': 'The Deck Southbank',
#   'place_id': 'ChIJgZOibbFC1moRsAR-TgIQ340',
#   'price_level': 3,
#   'lat': -37.8201534,
#   'long': 144.9668346,
#   'types': ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   'address': 'UPPER, LEVEL U1/2 Southgate Avenue, Southbank'},
#  {'name': "PJ O'Brien's Irish Pub",
#   'place_id': 'ChIJgZOibbFC1moRjJ5c8xm1eWE',
#   'price_level': 2,
#   'lat': -37.8203722,
#   'long': 144.9659504,
#   'types': ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   'address': 'G14 / 15, 16/3 Southgate Avenue, Southbank'},
#  {'name': 'Tutto Bene',
#   'place_id': 'ChIJreaFNbJC1moRpXUSN5IQbmk',
#   'price_level': 2,
#   'lat': -37.8202591,
#   'long': 144.9659072,
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'address': 'M28/3 Southgate Avenue, Southbank'},
#  {'name': 'BearBrass',
#   'place_id': 'ChIJgZOibbFC1moRMjs9MlqIuIc',
#   'price_level': 2,
#   'lat': -37.8201819,
#   'long': 144.9658567,
#   'types': ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   'address': 'GR3A/3 Southgate Avenue, Southbank'},
#  {'name': "Grill'd Southgate",
#   'place_id': 'ChIJwyFHM7JC1moR082aaKSzBEc',
#   'price_level': 2,
#   'lat': -37.819991,
#   'long': 144.9668681,
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'address': 'Shop G32 Southgate Restaurant Precinct, Southgate Avenue'},
#  {'name': "Roll'd Southgate",
#   'place_id': 'ChIJffIV0rNC1moRSEgzuMU4gq8',
#   'price_level': None,
#   'lat': -37.82023239999999,
#   'long': 144.9662985,
#   'types': ['meal_takeaway',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   'address': 'Southgate Melbourne, Tenancy G2/3 Southgate Avenue, Southbank'},
#  {'name': 'Bluetrain',
#   'place_id': 'ChIJiVdW17NC1moR-szxoi5qpgo',
#   'price_level': 2,
#   'lat': -37.8201184,
#   'long': 144.9662684,
#   'types': ['restaurant',
#    'cafe',
#    'food',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   'address': '3 Southgate Avenue, Southbank'},
#  {'name': 'Southgate',
#   'place_id': 'ChIJreaFNbJC1moRsVLa8Nh49SQ',
#   'price_level': None,
#   'lat': -37.8203389,
#   'long': 144.9660726,
#   'types': ['restaurant',
#    'cafe',
#    'art_gallery',
#    'bar',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   'address': '3 Southgate Avenue, Southbank'},
#  {'name': 'Saké Restaurant & Bar',
#   'place_id': 'ChIJNU4yR7FC1moRjYwkSIJQblo',
#   'price_level': 3,
#   'lat': -37.8199177,
#   'long': 144.9677708,
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'address': '100 Saint Kilda Road, Southbank'},
#  {'name': 'Teatro Restaurant',
#   'place_id': 'ChIJ1zaYQrFC1moRYTQxlnRsC_0',
#   'price_level': 2,
#   'lat': -37.8198212,
#   'long': 144.9673907,
#   'types': ['bar',
#    'store',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   'address': '37.819757, Southbank Promenade Melbourne VIC 3004, 144/967366 Southbank Promenade, Southbank'},
#  {'name': 'Best Western Melbourne City Hotel',
#   'place_id': 'ChIJWXdjjVFd1moRh_LdkkyRy5s',
#   'price_level': None,
#   'lat': -37.8206276,
#   'long': 144.9551461,
#   'types': ['cafe',
#    'lodging',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   'address': '16 Spencer Street, Melbourne'},
#  {'name': 'Grand Hotel Melbourne',
#   'place_id': 'ChIJ3dmt61Fd1moRKaWbEW3hml4',
#   'price_level': None,
#   'lat': -37.8203025,
#   'long': 144.9543906,
#   'types': ['lodging',
#    'bar',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   'address': '33 Spencer Street, Docklands'},
#  {'name': 'Grain Store',
#   'place_id': 'ChIJEcl3801d1moRgOGlD-vbemk',
#   'price_level': 2,
#   'lat': -37.8197517,
#   'long': 144.956651,
#   'types': ['cafe',
#    'meal_delivery',
#    'meal_takeaway',
#    'bar',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'store',
#    'establishment'],
#   'address': '517 Flinders Lane, Melbourne'},
#  {'name': 'The Hardware Société',
#   'place_id': 'ChIJGTbCqEpd1moRvbLaxevnLtw',
#   'price_level': 2,
#   'lat': -37.8200386,
#   'long': 144.9566619,
#   'types': ['cafe',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   'address': '10 Katherine Place, Melbourne'},
#  {'name': 'Royale PizzaMelbourne',
#   'place_id': 'ChIJT5at6FFd1moRl7tSBihHz1I',
# ...
#  {'name': 'Coda Melbourne',
#   'place_id': 'ChIJ9duozrdC1moRtuPvobzf_Zs',
#   'price_level': 3,
#   'lat': -37.8157661,
#   'long': 144.9698897,
#   'types': ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   'address': 'Basement/141 Flinders Lane, Melbourne'},
#  {'name': 'Trinket Bar Melbourne',
#   'place_id': 'ChIJG_VNHMhC1moRqMHCaY1Cw5k',
#   'price_level': 2,
#   'lat': -37.8152624,
#   'long': 144.9713399,
#   'types': ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   'address': '87 Flinders Lane, Melbourne'},
#  {'name': 'Tonka',
#   'place_id': 'ChIJfW9q5rdC1moRuFUkIp6ngjg',
#   'price_level': 3,
#   'lat': -37.8156991,
#   'long': 144.9714107,
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'address': '20 Duckboard Place, Melbourne'},
#  {'name': 'The Duke of Wellington',
#   'place_id': 'ChIJ9YePsLdC1moRhmhASJxsSqk',
#   'price_level': 2,
#   'lat': -37.81648359999999,
#   'long': 144.9700907,
#   'types': ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   'address': '146 Flinders Street, Melbourne'},
#  {'name': 'Tazio',
#   'place_id': 'ChIJrbHS48dC1moR9M42ZaCEip4',
#   'price_level': 2,
#   'lat': -37.815375,
#   'long': 144.9711894,
#   'types': ['meal_delivery',
#    'meal_takeaway',
#    'bar',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   'address': '91 Flinders Lane, Melbourne'},
#  {'name': 'The Meatball & Wine Bar - Flinders Lane',
#   'place_id': 'ChIJy453xbdC1moRRFDpPBRtbXs',
#   'price_level': 2,
#   'lat': -37.81564170000001,
#   'long': 144.9700889,
#   'types': ['restaurant', 'bar', 'food', 'point_of_interest', 'establishment'],
#   'address': '135 Flinders Lane, Melbourne'},
#  {'name': 'The Fair Trader',
#   'place_id': 'ChIJN0AnAchC1moRUeQkcSOBLuI',
#   'price_level': 2,
#   'lat': -37.8155787,
#   'long': 144.9718577,
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'address': '11 Exhibition Street, Melbourne'},
#  {'name': 'Eau De Vie Melbourne',
#   'place_id': 'ChIJq_Q3_bdC1moRTK6LBjNhFL4',
#   'price_level': 3,
#   'lat': -37.81580030000001,
#   'long': 144.9715874,
#   'types': ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   'address': '1 Malthouse Lane, Melbourne'},
#  {'name': 'Lee Ho Fook',
#   'place_id': 'ChIJA8SzVedC1moRLzSL5TQsovg',
#   'price_level': 3,
#   'lat': -37.81559720000001,
#   'long': 144.9713087,
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'address': '11-15 Duckboard Place, Melbourne'},
#  {'name': 'Chin Chin',
#   'place_id': 'ChIJ__3SxLdC1moRvQXAfpwM1hI',
#   'price_level': 2,
#   'lat': -37.815614,
#   'long': 144.970377,
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'address': '125 Flinders Lane, Melbourne'},
#  {'name': "Grill'd Flinders Lane",
#   'place_id': 'ChIJBw5qAshC1moRnE3tP2RBM_I',
#   'price_level': 2,
#   'lat': -37.815276,
#   'long': 144.9715543,
#   'types': ['restaurant', 'bar', 'food', 'point_of_interest', 'establishment'],
#   'address': '83 Flinders Lane, Melbourne'},
#  {'name': 'Lucy Liu Kitchen and Bar',
#   'place_id': 'ChIJX-_eyLdC1moR2lo_rt_gBX0',
#   'price_level': 3,
#   'lat': -37.8159928,
#   'long': 144.9699538,
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'address': '23 Oliver Lane, Melbourne'},
#  {'name': 'Bullrun café',
#   'place_id': 'ChIJZZAk3rdC1moRBLbi71KAUfc',
#   'price_level': 1,
#   'lat': -37.8154565,
#   'long': 144.9707815,
#   'types': ['cafe',
#    'restaurant',
#    'store',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   'address': '107 Flinders Lane, Melbourne'},
#  {'name': 'Swiss Club of Victoria',
#   'place_id': 'ChIJ5ywBHchC1moRa6om1ww9gvI',
#   'price_level': 2,
#   'lat': -37.8152719,
#   'long': 144.9713154,
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'address': '89 Flinders Lane, Melbourne'},
#  {'name': 'Pastuso',
#   'place_id': 'ChIJ2QMv5rdC1moRlTlxgCFLl0M',
#   'price_level': 3,
#   'lat': -37.8158403,
#   'long': 144.9710359,
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'address': '19 AC/DC Lane, Melbourne'},
#  {'name': 'A Hereford Beefstouw',
#   'place_id': 'ChIJbUqB5LdC1moRBUUGRuqWSjg',
#   'price_level': 3,
#   'lat': -37.8157449,
#   'long': 144.9712936,
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'address': '22 Duckboard Place, Melbourne'},
#  {'name': 'The French Brasserie',
#   'place_id': 'ChIJvw9l_bdC1moR__curJ3YI54',
#   'price_level': 4,
#   'lat': -37.8154573,
#   'long': 144.9715812,
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'address': '2 Malthouse Lane, Melbourne'},
#  {'name': 'Tonka',
#   'place_id': 'ChIJfW9q5rdC1moRuFUkIp6ngjg',
#   'price_level': 3,
#   'lat': -37.8156991,
#   'long': 144.9714107,
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'address': '20 Duckboard Place, Melbourne'},
#  {'name': "Cecconi's Flinders Lane Restaurant & Cellar Bar",
#   'place_id': 'ChIJ0xwW4cdC1moRe81ERqyUZpk',
#   'price_level': 3,
#   'lat': -37.8150555,
#   'long': 144.9725293,
#   'types': ['meal_delivery',
#    'meal_takeaway',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   'address': '61 Flinders Lane, Melbourne'},
#  {'name': 'Trinket Bar Melbourne',
#   'place_id': 'ChIJG_VNHMhC1moRqMHCaY1Cw5k',
#   'price_level': 2,
#   'lat': -37.8152624,
#   'long': 144.9713399,
#   'types': ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   'address': '87 Flinders Lane, Melbourne'},
#  {'name': 'The Fair Trader',
#   'place_id': 'ChIJN0AnAchC1moRUeQkcSOBLuI',
#   'price_level': 2,
#   'lat': -37.8155787,
#   'long': 144.9718577,
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'address': '11 Exhibition Street, Melbourne'},
#  {'name': 'Eau De Vie Melbourne',
#   'place_id': 'ChIJq_Q3_bdC1moRTK6LBjNhFL4',
#   'price_level': 3,
#   'lat': -37.81580030000001,
#   'long': 144.9715874,
#   'types': ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   'address': '1 Malthouse Lane, Melbourne'},
#  {'name': 'Tazio',
#   'place_id': 'ChIJrbHS48dC1moR9M42ZaCEip4',
#   'price_level': 2,
#   'lat': -37.815375,
#   'long': 144.9711894,
#   'types': ['meal_delivery',
#    'meal_takeaway',
#    'bar',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   'address': '91 Flinders Lane, Melbourne'},
#  {'name': 'Lee Ho Fook',
#   'place_id': 'ChIJA8SzVedC1moRLzSL5TQsovg',
#   'price_level': 3,
#   'lat': -37.81559720000001,
#   'long': 144.9713087,
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'address': '11-15 Duckboard Place, Melbourne'},
#  {'name': "Grill'd Flinders Lane",
#   'place_id': 'ChIJBw5qAshC1moRnE3tP2RBM_I',
#   'price_level': 2,
#   'lat': -37.815276,
#   'long': 144.9715543,
#   'types': ['restaurant', 'bar', 'food', 'point_of_interest', 'establishment'],
#   'address': '83 Flinders Lane, Melbourne'},
#  {'name': 'ELCHI',
#   'place_id': 'ChIJAd2WxERD1moRpTOJg1Vbh58',
#   'price_level': None,
#   'lat': -37.815732,
#   'long': 144.972688,
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'address': '72 Flinders Street, Melbourne'},
#  {'name': 'Robata Melbourne',
#   'place_id': 'ChIJz9lOndlD1moRyRP7H4fqa84',
#   'price_level': 3,
#   'lat': -37.8156392,
#   'long': 144.9725349,
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'address': '2 Exhibition Street, Melbourne'},
#  {'name': 'A Hereford Beefstouw',
#   'place_id': 'ChIJbUqB5LdC1moRBUUGRuqWSjg',
#   'price_level': 3,
#   'lat': -37.8157449,
#   'long': 144.9712936,
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'address': '22 Duckboard Place, Melbourne'},
#  {'name': 'Pastuso',
#   'place_id': 'ChIJ2QMv5rdC1moRlTlxgCFLl0M',
#   'price_level': 3,
#   'lat': -37.8158403,
#   'long': 144.9710359,
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'address': '19 AC/DC Lane, Melbourne'},
#  {'name': 'Swiss Club of Victoria',
#   'place_id': 'ChIJ5ywBHchC1moRa6om1ww9gvI',
#   'price_level': 2,
#   'lat': -37.8152719,
#   'long': 144.9713154,
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'address': '89 Flinders Lane, Melbourne'},
#  {'name': 'Garden State Hotel',
#   'place_id': 'ChIJ17FTBFxD1moRafdxQd8z_wQ',
#   'price_level': 2,
#   'lat': -37.81542,
#   'long': 144.971164,
#   'types': ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   'address': '101 Flinders Lane, Melbourne'},
#  {'name': 'Cumulus Inc.',
#   'place_id': 'ChIJW-wQG9tD1moRrdb47hcLeGM',
#   'price_level': None,
#   'lat': -37.81491320000001,
#   'long': 144.9731229,
#   'types': ['restaurant', 'bar', 'food', 'point_of_interest', 'establishment'],
#   'address': '45 Flinders Lane, Melbourne'},
#  {'name': 'ELCHI',
#   'place_id': 'ChIJAd2WxERD1moRpTOJg1Vbh58',
#   'price_level': None,
#   'lat': -37.815732,
#   'long': 144.972688,
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'address': '72 Flinders Street, Melbourne'},
#  {'name': 'Robata Melbourne',
#   'place_id': 'ChIJz9lOndlD1moRyRP7H4fqa84',
#   'price_level': 3,
#   'lat': -37.8156392,
#   'long': 144.9725349,
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'address': '2 Exhibition Street, Melbourne'},
#  {'name': 'Scugnizzo Ristorante',
#   'place_id': 'ChIJfU68A0xd1moRawbspxjQEU4',
#   'price_level': 2,
#   'lat': -37.8150634,
#   'long': 144.95578,
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'address': '558 Little Bourke Street, Melbourne'},
#  {'name': 'Hwaro Korean BBQ Restaurant',
#   'place_id': 'ChIJp5tMAkxd1moR29Sq4e5dulw',
#   'price_level': 2,
#   'lat': -37.815158,
#   'long': 144.955702,
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'address': '562 Little Bourke Street, Melbourne'},
#  {'name': 'La Di Da',
#   'place_id': 'ChIJt29sp05d1moRakdrB75IbHw',
#   'price_level': 2,
#   'lat': -37.8155681,
#   'long': 144.9556299,
#   'types': ['night_club',
#    'bar',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   'address': '577 Little Bourke Street, Melbourne'},
#  {'name': 'Royal Melbourne Hotel',
#   'place_id': 'ChIJs71vh05d1moRHPmLzj_tXDo',
#   'price_level': 2,
#   'lat': -37.816864,
#   'long': 144.955234,
#   'types': ['restaurant',
#    'bar',
#    'lodging',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   'address': '629 Bourke Street, Melbourne'},
#  {'name': 'Bar Humbug',
#   'place_id': 'ChIJ2R8gvU5d1moR6PSdDuscKoo',
#   'price_level': 2,
#   'lat': -37.8153864,
#   'long': 144.9549631,
#   'types': ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   'address': '586 Little Bourke Street, Melbourne'},
#  {'name': 'SUD Food and Wine',
#   'place_id': 'ChIJsZQurk5d1moR144VxZr6LEo',
#   'price_level': 2,
#   'lat': -37.8143576,
#   'long': 144.9561448,
#   'types': ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   'address': '555 Lonsdale Street, Melbourne'},
#  {'name': 'Dosa Hut - Indian Multi Cuisine Restaurant Melbourne CBD',
#   'place_id': 'ChIJZz7FpE5d1moR7XE7HGlQDpk',
#   'price_level': 2,
#   'lat': -37.8152798,
#   'long': 144.9549361,
#   'types': ['meal_takeaway',
#    'lodging',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   'address': '209 King Street, Melbourne'},
#  {'name': 'Delhi Rocks',
#   'place_id': 'ChIJW1Bu7slC1moRKkCeC1p5E1k',
#   'price_level': 1,
#   'lat': -37.8154217,
#   'long': 144.9548835,
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'address': '205 King Street, Melbourne'},
#  {'name': 'Woodo Korean Barbecue',
#   'place_id': 'ChIJ1chmmU5d1moRwVc6HVy3ycQ',
#   'price_level': 2,
#   'lat': -37.8159438,
#   'long': 144.9552646,
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'address': '179 King Street, Melbourne'},
#  {'name': 'The Colonial Hotel',
#   'place_id': 'ChIJcyupMsjs1moR6lD7Np0mUgw',
#   'price_level': 2,
#   'lat': -37.81452000000001,
#   'long': 144.955082,
#   'types': ['restaurant', 'bar', 'food', 'point_of_interest', 'establishment'],
#   'address': '585 Lonsdale Street, Melbourne'},
#  {'name': '7-Eleven',
#   'place_id': 'ChIJhyNGnE5d1moRgGyZiPuzm_E',
#   'price_level': None,
#   'lat': -37.8162078,
#   'long': 144.9554575,
#   'types': ['convenience_store',
#    'atm',
#    'finance',
#    'bakery',
#    'store',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   'address': 'Meeting room/620 Bourke Street, Melbourne'},
#  {'name': "Nando's Bourke Place",
#   'place_id': 'ChIJhz6IIUxd1moRR6Z2jb_YP7U',
#   'price_level': 2,
#   'lat': -37.8159365,
#   'long': 144.955988,
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'address': 'Bourke Place, LG 16/600 Bourke Street, Melbourne'},
#  {'name': 'Slate Restaurant Bar',
#   'place_id': 'ChIJSQf-dUxd1moRL0VBgm8_Fpk',
#   'price_level': 2,
#   'lat': -37.8152065,
#   'long': 144.9570031,
#   'types': ['restaurant', 'bar', 'food', 'point_of_interest', 'establishment'],
#   'address': '9 Goldsbrough Lane, Melbourne'},
#  {'name': 'Schmucks Bagels',
#   'place_id': 'ChIJj03w7Etd1moRaoywWst91Us',
#   'price_level': 1,
#   'lat': -37.8145862,
#   'long': 144.95687,
#   'types': ['meal_takeaway',
#    'cafe',
#    'bakery',
#    'store',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   'address': 'Guests Lane, Melbourne'},
#  {'name': 'Kedai Satay in King St',
#   'place_id': 'ChIJDeEYoU5d1moRfF7UT9i5avs',
#   'price_level': 1,
#   'lat': -37.8157059,
#   'long': 144.9556643,
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'address': '186 King Street, Melbourne'},
#  {'name': 'Subway',
#   'place_id': 'ChIJzxfWOktd1moR4yqcY9s90sM',
#   'price_level': 1,
#   'lat': -37.81601879999999,
#   'long': 144.9552402,
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'address': '177 King Street, Melbourne'},
#  {'name': 'Scugnizzo Ristorante',
#   'place_id': 'ChIJfU68A0xd1moRawbspxjQEU4',
#   'price_level': 2,
#   'lat': -37.8150634,
#   'long': 144.95578,
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'address': '558 Little Bourke Street, Melbourne'},
#  {'name': 'Hwaro Korean BBQ Restaurant',
#   'place_id': 'ChIJp5tMAkxd1moR29Sq4e5dulw',
#   'price_level': 2,
#   'lat': -37.815158,
#   'long': 144.955702,
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'address': '562 Little Bourke Street, Melbourne'},
#  {'name': 'La Di Da',
#   'place_id': 'ChIJt29sp05d1moRakdrB75IbHw',
#   'price_level': 2,
#   'lat': -37.8155681,
#   'long': 144.9556299,
#   'types': ['night_club',
#    'bar',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   'address': '577 Little Bourke Street, Melbourne'},
#  {'name': 'SUD Food and Wine',
#   'place_id': 'ChIJsZQurk5d1moR144VxZr6LEo',
#   'price_level': 2,
#   'lat': -37.8143576,
#   'long': 144.9561448,
#   'types': ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   'address': '555 Lonsdale Street, Melbourne'},
#  {'name': 'Bar Humbug',
#   'place_id': 'ChIJ2R8gvU5d1moR6PSdDuscKoo',
#   'price_level': 2,
#   'lat': -37.8153864,
#   'long': 144.9549631,
#   'types': ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   'address': '586 Little Bourke Street, Melbourne'},
#  {'name': 'Rock the Wok - Goldsbrough Village',
#   'place_id': 'ChIJewH-dUxd1moRiL3dYxJ8-wM',
#   'price_level': None,
#   'lat': -37.815108,
#   'long': 144.9572109,
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'address': '2 Guests Lane, Melbourne'},
#  {'name': 'Chilangos Mexican Cantina',
#   'place_id': 'ChIJOc5tiktd1moRrUKxXqAvlRA',
#   'price_level': 1,
#   'lat': -37.81518209999999,
#   'long': 144.9573841,
#   'types': ['meal_takeaway',
#    'meal_delivery',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   'address': 'Goldsbrough Lane TG 21, 181 William Street, Melbourne'},
#  {'name': 'Schmucks Bagels',
#   'place_id': 'ChIJj03w7Etd1moRaoywWst91Us',
#   'price_level': 1,
#   'lat': -37.8145862,
#   'long': 144.95687,
#   'types': ['meal_takeaway',
#    'bakery',
#    'cafe',
#    'store',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   'address': 'Guests Lane, Melbourne'},
#  ...]

# %%
print(len(restaurant_list))
# Out:
# 3200

# %% [markdown]
# ## Data Cleanup

# %%
restaurant_df = pd.DataFrame(restaurant_list)
print(restaurant_df.shape)
restaurant_df.head()
# Out:
# (3200, 7)
#                                 name                     place_id  \
# 0  Best Western Melbourne City Hotel  ChIJWXdjjVFd1moRh_LdkkyRy5s
# 1              Grand Hotel Melbourne  ChIJ3dmt61Fd1moRKaWbEW3hml4
# 2         Domino's Pizza Flinders St  ChIJzUeRGVJd1moR8OAx5QG2svk
# 3                        City Kebabs  ChIJJaylGVJd1moRjyu89QjaLrg
# 4              Royale PizzaMelbourne  ChIJT5at6FFd1moRl7tSBihHz1I
#
#    price_level        lat        long  \
# 0          NaN -37.820628  144.955146
# 1          NaN -37.820302  144.954391
# 2          1.0 -37.820869  144.956346
# 3          1.0 -37.820527  144.956193
# 4          NaN -37.819691  144.954892
#
#                                                types  \
# 0  [cafe, lodging, restaurant, food, point_of_int...
# 1  [lodging, bar, restaurant, food, point_of_inte...
# 2  [meal_delivery, meal_takeaway, restaurant, foo...
# 3  [meal_takeaway, restaurant, food, point_of_int...
# 4  [meal_delivery, meal_takeaway, restaurant, foo...
#
#                                      address
# 0               16 Spencer Street, Melbourne
# 1               33 Spencer Street, Docklands
# 2  Tenancy 2C/555 Flinders Street, Melbourne
# 3           3/546 Flinders Street, Melbourne
# 4            44/56 Spencer Street, Melbourne

# %%
# Remove duplicates
restaurant_df.drop_duplicates(subset=['place_id'],inplace=True)
restaurant_df.shape
# Out:
# (715, 7)

# %%
# Remove all 'restaurants' that have more than 6 types + remove hotel
filtered_df = restaurant_df[restaurant_df['types'].apply(lambda x: len(x) <= 6)]
filtered_df = filtered_df[~filtered_df['name'].apply(lambda x: 'Hotel' in x)]
filtered_df = filtered_df.reset_index(drop=True)
filtered_df.shape
# Out:
# (656, 7)

# %%
# Change price_level to int - fill NaNs with 0
filtered_df = filtered_df.fillna(0)
filtered_df['price_level'] = filtered_df['price_level'].astype(int)
filtered_df.head()
# Out:
#                          name                     place_id  price_level  \
# 0  Domino's Pizza Flinders St  ChIJzUeRGVJd1moR8OAx5QG2svk            1
# 1                 City Kebabs  ChIJJaylGVJd1moRjyu89QjaLrg            1
# 2       Royale PizzaMelbourne  ChIJT5at6FFd1moRl7tSBihHz1I            0
# 3            Cherry and Twigs  ChIJJbxbHVJd1moRlmxHO37SS70            2
# 4             Restaurant 1903  ChIJlVbz5VFd1moRBbVdFgoTEVI            1
#
#          lat        long                                              types  \
# 0 -37.820869  144.956346  [meal_delivery, meal_takeaway, restaurant, foo...
# 1 -37.820527  144.956193  [meal_takeaway, restaurant, food, point_of_int...
# 2 -37.819691  144.954892  [meal_delivery, meal_takeaway, restaurant, foo...
# 3 -37.820037  144.955732  [cafe, restaurant, food, point_of_interest, es...
# 4 -37.819733  144.954767  [restaurant, food, point_of_interest, establis...
#
#                                      address
# 0  Tenancy 2C/555 Flinders Street, Melbourne
# 1           3/546 Flinders Street, Melbourne
# 2            44/56 Spencer Street, Melbourne
# 3       Shop 1B/555 Flinders Lane, Melbourne
# 4               44 Spencer Street, Melbourne

# %%
# Save!
output_folder = 'output'
if not os.path.exists(output_folder):
    os.makedirs(output_folder)


output_file = 'restaurants.csv'
output_path = os.path.join(output_folder, output_file)
filtered_df.to_csv(output_path, index=False)
