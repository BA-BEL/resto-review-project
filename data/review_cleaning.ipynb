# %%
import pandas as pd
import os
import re

# %%
# Path to both data files
current_directory = os.getcwd()
reviews_csv = os.path.join(current_directory, 'data', 'gm_reviews.csv')
restaurants_csv = os.path.join(current_directory, 'data','restaurants.csv')

# %%
reviews_df = pd.read_csv(reviews_csv, encoding='utf-8')
print(reviews_df.shape)
reviews_df.head()
# Out:
# (19560, 5)
#    restaurant_ids                             id_review           caption  \
# 0               1  ChdDSUhNMG9nS0VJQ0FnSUN4ek83dTd3RRAB               NaN
# 1               1   ChZDSUhNMG9nS0VJQ0FnSUN4MU95cFZREAE               NaN
# 2               1   ChZDSUhNMG9nS0VJQ0FnSUN4NUlpb0l3EAE               NaN
# 3               1  ChdDSUhNMG9nS0VJQ0FnSUN4NExQZXdBRRAB               NaN
# 4               1  ChdDSUhNMG9nS0VJQ0FnSURSOTRpbmxnRRAB  Great experience
#
#   relative_date              username
# 0  17 hours ago                   S V
# 1     a day ago  Adaikkappan Nagappan
# 2     a day ago     project_be_simple
# 3    2 days ago           Anmol Singh
# 4    6 days ago          Sandeep Kaur

# %%
restaurants_df = pd.read_csv(restaurants_csv, encoding='utf-8')
print(restaurants_df.shape)
restaurants_df.head()
# Out:
# (652, 9)
#    restaurant_id                        name                     place_id  \
# 0              1  Domino's Pizza Flinders St  ChIJzUeRGVJd1moR8OAx5QG2svk
# 1              2                 City Kebabs  ChIJJaylGVJd1moRjyu89QjaLrg
# 2              3       Royale PizzaMelbourne  ChIJT5at6FFd1moRl7tSBihHz1I
# 3              4            Cherry and Twigs  ChIJJbxbHVJd1moRlmxHO37SS70
# 4              5             Restaurant 1903  ChIJlVbz5VFd1moRBbVdFgoTEVI
#
#    price_level        lat        long  \
# 0            1 -37.820869  144.956346
# 1            1 -37.820527  144.956193
# 2            0 -37.819691  144.954892
# 3            2 -37.820037  144.955732
# 4            1 -37.819733  144.954767
#
#                                                types  \
# 0  ['meal_delivery', 'meal_takeaway', 'restaurant...
# 1  ['meal_takeaway', 'restaurant', 'food', 'point...
# 2  ['meal_delivery', 'meal_takeaway', 'restaurant...
# 3  ['cafe', 'restaurant', 'food', 'point_of_inter...
# 4  ['restaurant', 'food', 'point_of_interest', 'e...
#
#                                      address            cuisine
# 0  Tenancy 2C/555 Flinders Street, Melbourne          Fast Food
# 1           3/546 Flinders Street, Melbourne          Fast Food
# 2            44/56 Spencer Street, Melbourne              Pizza
# 3       Shop 1B/555 Flinders Lane, Melbourne               Café
# 4               44 Spencer Street, Melbourne  Modern Australian

# %%
# Remove all blank reviews
reviews_df.dropna(axis=0, how='any',inplace=True)
reviews_df.reset_index(drop=True,inplace=True)
reviews_df.shape
# Out:
# (14321, 5)

# %%
# Remove all emoji characters and non-english text from the reviews.
cleaned_reviews_df = reviews_df.copy()

def remove_emoji_or_encoding_byproducts(text):
    # The regular expression pattern below will match any emoji or non-text symbols
    pattern = re.compile(r'[\U00010000-\U0010ffff]|[^\x00-\x7F]+', flags=re.UNICODE)
    return pattern.sub('', text)

# Apple function to review column
cleaned_reviews_df['caption'] = cleaned_reviews_df['caption'].apply(remove_emoji_or_encoding_byproducts)

# %%
# Ensure again that there are no blank reviews
cleaned_reviews_df.dropna(axis=0, how='any',inplace=True)
cleaned_reviews_df.reset_index(drop=True,inplace=True)
cleaned_reviews_df.shape
# Out:
# (14321, 5)

# %%
# Have the names and cuisines of the restaurants on the reviews dataframe
merged_df = pd.merge(cleaned_reviews_df, 
         restaurants_df, 
         left_on='restaurant_ids',
         right_on='restaurant_id')

merged_df.drop(columns=['price_level', 'place_id', 'restaurant_id','lat', 'long', 'types', 'address'],inplace=True)
merged_df.head()
# Out:
#    restaurant_ids                             id_review  \
# 0               1  ChdDSUhNMG9nS0VJQ0FnSURSOTRpbmxnRRAB
# 1               1  ChdDSUhNMG9nS0VJQ0FnSURScktPaDV3RRAB
# 2               1   ChZDSUhNMG9nS0VJQ0FnSURSNUotOUt3EAE
# 3               1  ChdDSUhNMG9nS0VJQ0FnSURSNklYTG93RRAB
# 4               1   ChZDSUhNMG9nS0VJQ0FnSUNPNXJhd0VREAE
#
#                                              caption relative_date  \
# 0                                   Great experience    6 days ago
# 1  Must be the worst dominos in the world.   Pizz...   3 weeks ago
# 2        They are so nice and the Food is Perfect !!   3 weeks ago
# 3  Staff was friendly and helpful. The deals make...   3 weeks ago
# 4          Been coming here for awhile usually happy   a month ago
#
#                username                        name    cuisine
# 0          Sandeep Kaur  Domino's Pizza Flinders St  Fast Food
# 1      Robert McFarland  Domino's Pizza Flinders St  Fast Food
# 2     Patricia Tchialeu  Domino's Pizza Flinders St  Fast Food
# 3           Brent Folan  Domino's Pizza Flinders St  Fast Food
# 4  Johnathan Vanderwerf  Domino's Pizza Flinders St  Fast Food

# %%
# Saving to output folder
output_folder = 'output'
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# Save the DataFrame to the 'output' folder as a CSV file
output_file = 'cleaned_reviews.csv'
output_path = os.path.join(output_folder, output_file)
merged_df.to_csv(output_path, index=False)
